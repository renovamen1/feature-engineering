# %%
import pickle
import numpy as np

# %% [markdown]
# ### this is extremely important to maintain the right order of values in test_input. the order must be similar to the sequence of data passed in column transformers during the creationof the pipleine.

# %%
test_input = np.array(
    [[58, 'M', 'ASY', 140,250, 0, 'Normal', 172, 'N', 0.0, 'Up', 'Low']],
    dtype=object
)

# %%
# here we are testing/ predicting with an input in the exported model made using pipleines.
pipe = pickle.load(open("exported_model_using_pipeline.pkl","rb"))

# %%
pipe.predict(test_input)
# Out:
# /Users/prabinthakur/code101/python for ds/ds-env/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OrdinalEncoder was fitted with feature names
#   warnings.warn(
# /Users/prabinthakur/code101/python for ds/ds-env/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# The pipeline model was trained on the full 12-column X_train, then scaled and SelectKBest(k=11).
# Encoding, scaling, and feature selection all live inside the pickled pipe, so when giving test imput 
#  we require to pass raw original features in X_train order and then call pipe.predict(...).
